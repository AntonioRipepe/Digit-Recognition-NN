# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist # 28x28 images of hand written digits 0-9

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten()) # Flatten takes the 2d array into a flat 1d array
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=10) #epochs are the amount of iterations through all the data
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 6s 92us/sample - loss: 0.2663 - accuracy: 0.9223
# Epoch 2/10
# 60000/60000 [==============================] - 5s 75us/sample - loss: 0.1087 - accuracy: 0.9665
# Epoch 3/10
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.0732 - accuracy: 0.9771
# Epoch 4/10
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.0547 - accuracy: 0.9826
# Epoch 5/10
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.0400 - accuracy: 0.9874
# Epoch 6/10
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.0320 - accuracy: 0.9895
# Epoch 7/10
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.0269 - accuracy: 0.9911
# Epoch 8/10
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.0199 - accuracy: 0.9933
# Epoch 9/10
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.0192 - accuracy: 0.9933
# ...

# %%
lossvalue, accuracyValue = model.evaluate(x_test, y_test)
print("The loss value =",lossvalue," The accuracy value =", accuracyValue)
# Out:
# 10000/10000 [==============================] - 0s 48us/sample - loss: 0.1132 - accuracy: 0.9749
# The loss value = 0.11315168538417639  The accuracy value = 0.9749

# %%
model.save('Digit_Recognition.model')

# %%
predictions = new_model.predict(x_test)

# %%
import matplotlib.pyplot as plt
import numpy as np
# Will print the prediction of the first 'num' elements, as well as the first 'num' elements themselves
num = 100
for i in range(num):
    print("Prediction:", np.argmax(predictions[i]))
    plt.imshow(x_test[i], cmap = plt.cm.binary) # cmap = plt.cm.binary makes the color map black & white
    plt.show()
# Out:
# Prediction: 7
# Prediction: 2
# Prediction: 1
# Prediction: 0
# Prediction: 4
# Prediction: 1
# Prediction: 4
# Prediction: 9
# Prediction: 5
# Prediction: 9
# Prediction: 0
# Prediction: 6
# Prediction: 9
# Prediction: 0
# Prediction: 1
# Prediction: 5
# Prediction: 9
# Prediction: 7
# Prediction: 8
# Prediction: 4
# Prediction: 9
# Prediction: 6
# Prediction: 6
# Prediction: 5
# Prediction: 4
# Prediction: 0
# Prediction: 7
# Prediction: 4
# Prediction: 0
# Prediction: 1
# Prediction: 3
# Prediction: 1
# Prediction: 3
# Prediction: 4
# Prediction: 7
# Prediction: 2
# Prediction: 7
# Prediction: 1
# Prediction: 2
# Prediction: 1
# Prediction: 1
# Prediction: 7
# Prediction: 4
# Prediction: 2
# Prediction: 3
# Prediction: 5
# Prediction: 1
# Prediction: 2
# Prediction: 4
# Prediction: 4
# Prediction: 6
# Prediction: 3
# Prediction: 5
# Prediction: 5
# Prediction: 6
# Prediction: 0
# Prediction: 4
# Prediction: 1
# Prediction: 9
# Prediction: 5
# Prediction: 7
# Prediction: 8
# ...
